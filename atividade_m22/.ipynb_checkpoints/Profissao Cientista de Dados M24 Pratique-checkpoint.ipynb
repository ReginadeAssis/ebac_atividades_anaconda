# %% [markdown]
# # **MÓDULO 24 - Bancos de Dados + SQL**

# %% [markdown]
# Para nossa atividade inicial de SQL trabalharemos com uma base de vendas.
# Abaixo temos o ambiente de preparo para trabalharmos com o SQL lite.

# %%
import sqlite3 #Importando a biblioteca necessária
import pandas as pd

# %%
df_vendas = pd.read_csv("TB_VENDAS_TAREFA.csv", delimiter=';')

# %%
conn = sqlite3.connect(':memory:')
df_vendas.to_sql('tb_vendas_tarefa', conn, index=False, if_exists='replace')
# Out:
# 24

# %%
def run_query(query):
    return pd.read_sql_query(query, conn)

# %%
df_vendas.head(10)
# Out:
#    ID_COMPRA  ID_CLIENTE   PRODUTO VALOR_UNID  UNIDADES
# 0       1247        9081  CAMISETA       34,5         2
# 1       1248        9081     CALCA       89,9         1
# 2       1250        9560  CAMISETA       34,5         1
# 3       1249        9630   BERMUDA       79,5         2
# 4       1251        9425  CAMISETA       34,5         3
# 5       1252        9425   VESTIDO        102         1
# 6       1253        9481     CALCA       89,9         2
# 7       1254        9785      MEIA       25,9         1
# 8       1255        9786     CALCA       89,9         2
# 9       1256        9787   VESTIDO        102         1

# %% [markdown]
# # 1) Faça uma consulta que retorne todos os dados da nossa tabela de vendas, com todas linhas e todas colunas.

# %%
query = "SELECT * FROM tb_vendas_tarefa "
result_df = run_query(query)
print(result_df)
# Out:
#     ID_COMPRA  ID_CLIENTE   PRODUTO VALOR_UNID  UNIDADES
# 0        1247        9081  CAMISETA       34,5         2
# 1        1248        9081     CALCA       89,9         1
# 2        1250        9560  CAMISETA       34,5         1
# 3        1249        9630   BERMUDA       79,5         2
# 4        1251        9425  CAMISETA       34,5         3
# 5        1252        9425   VESTIDO        102         1
# 6        1253        9481     CALCA       89,9         2
# 7        1254        9785      MEIA       25,9         1
# 8        1255        9786     CALCA       89,9         2
# 9        1256        9787   VESTIDO        102         1
# 10       1257        9788     CALCA       89,9         2
# 11       1258        9789  CAMISETA       34,5         3
# 12       1259        9790  CAMISETA       34,5         1
# 13       1260        9791   BERMUDA       79,5         2
# 14       1261        9792  CAMISETA       34,5         2
# ...

# %% [markdown]
# # 2) Faça uma consulta que retorne apenas 10 linhas da coluna produto.

# %%
query = "SELECT produto FROM tb_vendas_tarefa LIMIT 11";
result_df = run_query(query)
print(result_df)
# Out:
#      PRODUTO
# 0   CAMISETA
# 1      CALCA
# 2   CAMISETA
# 3    BERMUDA
# 4   CAMISETA
# 5    VESTIDO
# 6      CALCA
# 7       MEIA
# 8      CALCA
# 9    VESTIDO
# 10     CALCA

# %% [markdown]
# # 3) Faça uma consulta que retorne a média do valor por unidade e também das unidades vendidas. Não se esqueça de renomear o nome das colunas ao cria-las.

# %%
query = "SELECT AVG(VALOR_UNID) AS media_valor_unidade, AVG(UNIDADES) AS media_unidades_vendidas FROM tb_vendas_tarefa;"
result_df = run_query(query)
print(result_df)
# Out:
#    media_valor_unidade  media_unidades_vendidas
# 0            63.416667                 1.833333

# %% [markdown]
# # 4) Note que na nossa tabela não temos o total de valor gasto por compra, temos o valor do produto e a quantidade vendida, para termos o valor total precisamos multiplicar essas duas colunas e para multiplicar colunas usamos o *.
# # Faça uma consulta que retorne a coluna ID_COMPRA, ID_CLIENTE e o valor total gasto.
#
# Ex: SELECT TICKET_MEDIO*UNIDADE FROM TB_EXEMPLO

# %%
query = "SELECT ID_COMPRA, ID_CLIENTE, VALOR_UNID *UNIDADES AS VALOR_TOTAL_GASTO FROM tb_vendas_tarefa"
result_df = run_query(query)
print(result_df)
# Out:
#     ID_COMPRA  ID_CLIENTE  VALOR_TOTAL_GASTO
# 0        1247        9081                 68
# 1        1248        9081                 89
# 2        1250        9560                 34
# 3        1249        9630                158
# 4        1251        9425                102
# 5        1252        9425                102
# 6        1253        9481                178
# 7        1254        9785                 25
# 8        1255        9786                178
# 9        1256        9787                102
# 10       1257        9788                178
# 11       1258        9789                102
# 12       1259        9790                 34
# 13       1260        9791                158
# 14       1261        9792                 68
# 15       1262        9793                178
# 16       1263        9794                 89
# 17       1264        9795                158
# 18       1265        9796                136
# 19       1266        9797                 34
# ...

# %% [markdown]
# # 5) [DESAFIO] Faça uma consulta que traz a média do valor total gasto que foi calculado no exercício anterior. Note que não queremos a média por pedido e sim a média total, apenas essa informação deve vir na consulta.

# %% [markdown]
# query = "SELECT AVG(VALOR_TOTAL_GASTO) AS media_valor_total_gasto from tb_vendas_tarefa"
# result_df = run_query(query)
# # Exibir o resultado
# print(result_df)
# #como a coluna foi criada como cálculo, ela não existe e é preciso q vc repita  operação

# %%
query = "SELECT AVG(VALOR_UNID * UNIDADES) AS media_valor_total_gasto from tb_vendas_tarefa"
result_df = run_query(query)
# Exibir o resultado
print(result_df)
# Out:
#    media_valor_total_gasto
# 0                  108.625

# %% [markdown]
# # 6) Diferencie com suas palavras, considerando o repertório que tem criado da área de dados, a utilizadade do SQL e do Python para ciência de dados.
# O phyton é usado para tratamento e análise dos dados permitindo a limpeza, correções, manipulação construção de gráficos e modelos. Já o sql é a linguagem que dá suporte para consultas, filtragens e agrupamentos com maior facilidade e suportando um grande volume de dados que o excel, por exemplo não suportaria. O phyton é a primeira frente tratando e analisando os dados que em grande volume são facilmente consultados e agrupados utilizando o SQL.

# %% [markdown]
# #7) Diferencie com suas palavras banco de dados relacionais de não relacionais.
# Os bancos de dados relacionais organizam as informações em tabelas compondo linhas e colunas ue possuem uma integração particular entre elas essas relações são identificadas através de chaves como primária e estrangeira. Já os não relacionais são mais flexíveis estruturalmente permitindo uma diversidade de armazenamento e organização dos dados, possuem grandes e variados volumes de dados.

# %% [markdown]
# #8) Queremos saber da sua opinião, acredita que o SQL pode ser mais prático que o Python para consultas rápidas? Justifique.
# Muitas vezes durante a carreia você terá que escolher qual linguagem utilizar para cada momento afim de entregar o que é solicitado o mais rápido e com qualidade possível, exercite sua argumentação = )
#
# Sim, porque através de comandos simples como select, avg e sum podemos obter respostas que exigem pouco código, mas repospondem as principais perguntas. O SQL não substitui a utilização do phyton, é apenas mais uma ferramenta para acessar, agrupar e exibir informações sobre o conjunto de dados com maior facilidade e rapidez. Com SQL é possível otimizar as pesquisas em grande volumes de dados, entretanto o phyton já "tratou" esses mesmos dados previamente.
