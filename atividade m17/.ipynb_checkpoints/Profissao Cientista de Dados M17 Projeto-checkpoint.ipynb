# %% [markdown]
# # **MÓDULO 17 - Projeto de Credit Score - Parte 1 - Processamento dos dados**

# %% [markdown]
# Essa é a primeira etapa do processo de Credit Score que vocês desenvolverão durante nosso curso.
# Nessa primeira etapa vocês irão aplicar os passos aprendidos nos módulos de pré processamento para preparar a base de vocês para o desenvolvimento do modelo.

# %% [markdown]
# O termo "credit score" se refere a uma pontuação numérica que representa a credibilidade de um indivíduo em termos de cumprimento de obrigações financeiras, como pagar contas de empréstimos, cartões de crédito, entre outros. Essa pontuação é calculada com base em diversas informações financeiras e de crédito do indivíduo, como histórico de pagamentos, níveis de endividamento, tempo de crédito, tipos de crédito utilizados, entre outros.
#
# O objetivo de um modelo de credit score é prever o risco de um indivíduo se tornar inadimplente com suas obrigações financeiras. Em outras palavras, o modelo avalia a probabilidade de um indivíduo não cumprir com os pagamentos de empréstimos ou outros compromissos financeiros. Essa previsão é fundamental para instituições financeiras, como bancos e credores, na tomada de decisão sobre a concessão de crédito. Um modelo de credit score eficaz pode ajudar essas instituições a avaliar o risco de emprestar dinheiro a um determinado indivíduo e, assim, tomar decisões mais informadas sobre a aprovação ou negação de crédito, bem como sobre os termos e condições desses empréstimos.

# %% [markdown]
# **Atenção:** Notem que esse projeto é diferente da base que tenho trabalhado com vocês em aula, apesar de se tratar de uma base bancária durante a aula falamos sobre a variável Churn a ser prevista, nesse caso a previsão seria do valor do Score de Crédito.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import plotly.express as px
import numpy as np

# %%
#Lembrem-se sempre de alterar a importação dos dados de acordo com o diretório de vocês.
df = pd.read_csv("CREDIT_SCORE_PROJETO_PARTE1.csv", delimiter=';')

df.head(10)
# Out:
#     Age  Gender      Income            Education Marital Status  \
# 0  25.0  Female   50.000,00    Bachelor's Degree         Single
# 1  30.0    Male  100.000,00      Master's Degree        Married
# 2  35.0  Female   75.000,00            Doctorate        Married
# 3  40.0    Male  125.000,00  High School Diploma         Single
# 4  45.0  Female  100.000,00    Bachelor's Degree        Married
# 5  50.0    Male  150.000,00      Master's Degree        Married
# 6  26.0  Female   40.000,00   Associate's Degree         Single
# 7  31.0    Male   60.000,00    Bachelor's Degree         Single
# 8   NaN  Female   80.000,00      Master's Degree        Married
# 9   NaN    Male  105.000,00            Doctorate         Single
#
#    Number of Children Home Ownership Credit Score
# 0                   0         Rented         High
# 1                   2          Owned         High
# 2                   1          Owned         High
# 3                   0          Owned         High
# 4                   3          Owned         High
# 5                   0          Owned         High
# 6                   0         Rented      Average
# 7                   0         Rented      Average
# 8                   2          Owned         High
# 9                   0          Owned         High

# %% [markdown]
# Legenda dos dados:
#
# *   **Age** : Idade dos nossos clientes.
#
# *   **Income** : Salário Mensal.
#
# *   **Gender** : Gênero.
#
# *   **Education** : Nível de escolaridade dos clientes.
#
# *   **Marital** : Status Civilmente.
#
# *   **Number of Children** : Quantidade de filhos.
#
# *   **Home** : Tipo de residência, alugada ou própria.
#
# *   **Credit Score** : Nossa variável preditora, o score de crédito dos clientes.

# %%
print(df.info())
print(df.isnull().sum())
(df.isnull().sum()/len(df))*100 #preciso substituir pela média de idade
(df.duplicated().sum()) #preciso remover as duplicatas
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 164 entries, 0 to 163
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Age                 130 non-null    float64
#  1   Gender              164 non-null    str
#  2   Income              164 non-null    str
#  3   Education           164 non-null    str
#  4   Marital Status      164 non-null    str
#  5   Number of Children  164 non-null    int64
#  6   Home Ownership      164 non-null    str
#  7   Credit Score        164 non-null    str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 10.4 KB
# None
# Age                   34
# Gender                 0
# Income                 0
# Education              0
# Marital Status         0
# Number of Children     0
# Home Ownership         0
# Credit Score           0
# dtype: int64
# np.int64(45)

# %%
df['Age'] = df['Age'].where((df['Age'] >= 1) & (df['Age'] <= 100), np.nan)
(df.isnull().sum())
# Out:
# Age                   34
# Gender                 0
# Income                 0
# Education              0
# Marital Status         0
# Number of Children     0
# Home Ownership         0
# Credit Score           0
# dtype: int64

# %%
df['Age'] = df['Age'].fillna(df['Age'].mean())
print(df.isnull().sum())
# Out:
# Age                   0
# Gender                0
# Income                0
# Education             0
# Marital Status        0
# Number of Children    0
# Home Ownership        0
# Credit Score          0
# dtype: int64

# %%
print(df.duplicated().sum())
# Out:
# 45

# %%
df = df.drop_duplicates()
print(df.duplicated().sum())
# Out:
# 0

# %%
df.columns = df.columns.str.lower().str.strip().str.replace(" ", "_")
df.head(10)
# Out:
#          age  gender      income            education marital_status  \
# 0  25.000000  Female   50.000,00    Bachelor's Degree         Single
# 1  30.000000    Male  100.000,00      Master's Degree        Married
# 2  35.000000  Female   75.000,00            Doctorate        Married
# 3  40.000000    Male  125.000,00  High School Diploma         Single
# 4  45.000000  Female  100.000,00    Bachelor's Degree        Married
# 5  50.000000    Male  150.000,00      Master's Degree        Married
# 6  26.000000  Female   40.000,00   Associate's Degree         Single
# 7  31.000000    Male   60.000,00    Bachelor's Degree         Single
# 8  37.507692  Female   80.000,00      Master's Degree        Married
# 9  37.507692    Male  105.000,00            Doctorate         Single
#
#    number_of_children home_ownership credit_score
# 0                   0         Rented         High
# 1                   2          Owned         High
# 2                   1          Owned         High
# 3                   0          Owned         High
# 4                   3          Owned         High
# 5                   0          Owned         High
# 6                   0         Rented      Average
# 7                   0         Rented      Average
# 8                   2          Owned         High
# 9                   0          Owned         High

# %% [markdown]
# # Etapa 1: Relize os passos que vimos no módulo 18, de pré processamento dos dados.
#
# **A) Verifique os tipos de dados, fazendo as transformações quando necessário.**
# <br> A variável income foi entendida como string e transformada em float. As demais parecem coerentes e aptas para análise.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 119 entries, 0 to 152
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 119 non-null    float64
#  1   gender              119 non-null    str
#  2   income              119 non-null    str
#  3   education           119 non-null    str
#  4   marital_status      119 non-null    str
#  5   number_of_children  119 non-null    int64
#  6   home_ownership      119 non-null    str
#  7   credit_score        119 non-null    str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 8.4 KB

# %% [markdown]
# **B) Verifique se temos colunas com dados faltantes.
# Caso existam colunas com dados faltantes faça o tratamento desses dados, excluindo ou substituindo esses valores. Justifique sua escolha.**

# %% [markdown]
# sim, idade possuia dados faltantes que foram substituídos pela média porque representavam uma parcela importante dos registros.

# %% [markdown]
# **C) Verifique se temos valores digitados de forma incorreta nas variáveis categóricas que necessitem de tratamento.**
# <br>Não, elas possuem apenas dois valores.

# %%
for col in ['gender', 'marital_status', 'education', 'home_ownership', 'credit_score']:
    print(f"\nColuna: {col}")
    print(df[col].value_counts())
# Out:
# Coluna: gender
# gender
# Female    60
# Male      59
# Name: count, dtype: int64
#
# Coluna: marital_status
# marital_status
# Married    66
# Single     53
# Name: count, dtype: int64
#
# Coluna: education
# education
# Bachelor's Degree      33
# Master's Degree        27
# Doctorate              22
# High School Diploma    21
# Associate's Degree     16
# Name: count, dtype: int64
#
# Coluna: home_ownership
# home_ownership
# Owned     85
# Rented    34
# Name: count, dtype: int64
#
# Coluna: credit_score
# credit_score
# High       87
# Average    24
# Low         8
# Name: count, dtype: int64

# %% [markdown]
# # Etapa 2: Relize os passos que vimos no módulo 15, de análise.
#
# **A) Realiza a análise univariada, aplique a função describe ao nosso dataframe para verificar os dados das variáveis numéricas, se encontrar a possível presença de outliers analise com gráficos a distribuição dos dados.Traga insights sobre os dados analisados.**

# %%
df.info()
print(df.describe())
# Out:
# <class 'pandas.DataFrame'>
# Index: 119 entries, 0 to 152
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   age                 119 non-null    float64
#  1   gender              119 non-null    str
#  2   income              119 non-null    str
#  3   education           119 non-null    str
#  4   marital_status      119 non-null    str
#  5   number_of_children  119 non-null    int64
#  6   home_ownership      119 non-null    str
#  7   credit_score        119 non-null    str
# dtypes: float64(1), int64(1), str(6)
# memory usage: 8.4 KB
#               age  number_of_children
# count  119.000000          119.000000
# mean    38.338203            0.647059
# std      7.478865            0.888612
# min     25.000000            0.000000
# 25%     34.000000            0.000000
# 50%     37.507692            0.000000
# 75%     43.500000            1.000000
# max     53.000000            3.000000

# %% [markdown]
# Ele não entendeu income que é o salário mensal como número, por isso fiz a conversão.

# %%
df['income'] = df['income'].astype(str)\
                           .str.replace('.', '', regex=False)\
                           .str.replace(',', '.', regex=False)\
                           .astype(float)
df.head(10)
# Out:
#          age  gender    income            education marital_status  \
# 0  25.000000  Female   50000.0    Bachelor's Degree         Single
# 1  30.000000    Male  100000.0      Master's Degree        Married
# 2  35.000000  Female   75000.0            Doctorate        Married
# 3  40.000000    Male  125000.0  High School Diploma         Single
# 4  45.000000  Female  100000.0    Bachelor's Degree        Married
# 5  50.000000    Male  150000.0      Master's Degree        Married
# 6  26.000000  Female   40000.0   Associate's Degree         Single
# 7  31.000000    Male   60000.0    Bachelor's Degree         Single
# 8  37.507692  Female   80000.0      Master's Degree        Married
# 9  37.507692    Male  105000.0            Doctorate         Single
#
#    number_of_children home_ownership credit_score
# 0                   0         Rented         High
# 1                   2          Owned         High
# 2                   1          Owned         High
# 3                   0          Owned         High
# 4                   3          Owned         High
# 5                   0          Owned         High
# 6                   0         Rented      Average
# 7                   0         Rented      Average
# 8                   2          Owned         High
# 9                   0          Owned         High

# %%
df.describe()
# Out:
#               age  number_of_children
# count  119.000000          119.000000
# mean    38.338203            0.647059
# std      7.478865            0.888612
# min     25.000000            0.000000
# 25%     34.000000            0.000000
# 50%     37.507692            0.000000
# 75%     43.500000            1.000000
# max     53.000000            3.000000

# %% [markdown]
# A coluna de idade possui a média bem próxima da mediana indicando uma distrbuição mais simétrica com a metade dos clientes entre 34 e 43 anos de vida. Além disso, um dp baixo mostrando a baixa dispersão. Dessa forma, a amostra sugere que o público mais atingido é adulto.
#
# A coluna de salário mensal também possui uma distribuição equilibrada, entretando possui um dp alto que indica uma dispersão/ salários diferentes que pode ser observada pelas faixas já que 25% ganham 62500, 50% estão na faixa de 87500 e 75% 110000. Os clientes estão distribuídos em uma faixa de renda relativamente ampla.
#
# Quanto ao número de crianças a distribuição é assimétrica já que mais da metade da amostra não possui filhos e 75% possui apenas um, ou seja, a maior parte da base tem um ou nenhum filho e no máximo 2 filhos(4 registros com 3 filhos removidos).

# %% [markdown]
# **C) Você encontrou alguma coluna com outliers?
# Se sim realize o tratamento desses casos.**

# %%
fig = px.box(df, y='age', title='Idade')
fig.update_layout(width=800, height=500)
fig.show()

fig = px.box(df, y='income', title='Salário')
fig.update_layout(width=800, height=500)
fig.show()


fig = px.box(df, y='number_of_children', title='Filhos')
fig.update_layout(width=800, height=500)
fig.show()
#sim, 4 registros com 3 filhos removidos porque eram poucos.

# %%
(df['number_of_children'] == 3).sum()
# Out:
# np.int64(4)

# %%
df = df[df['number_of_children'] != 3]

# %%
(df['number_of_children'] == 3).sum()
# Out:
# np.int64(0)

# %%
fig = px.box(df, y='number_of_children', title='Filhos')
fig.update_layout(width=800, height=500)
fig.show()
df['number_of_children'].describe()
# Out:
# count    115.000000
# mean       0.565217
# std        0.785063
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        2.000000
# Name: number_of_children, dtype: float64

# %% [markdown]
# **B) Agora realize a análise univariada para as variaveis categóricas, plote gráficos para entender a distribuição das categorias e tente retirar insights de cada gráfico.**

# %%
df_count = df['marital_status'].value_counts().reset_index()
df_count.columns = ['marital_status', 'count']
fig = px.bar(
    df_count,
    x='marital_status',
    y='count',
    title='Distribuição de Estado Civil'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
df['marital_status'].value_counts()
# Out:
# marital_status
# Married    66
# Single     53
# Name: count, dtype: int64

# %%
df['marital_status'].value_counts(normalize=True) * 100
# Out:
# marital_status
# Married    55.462185
# Single     44.537815
# Name: proportion, dtype: float64

# %% [markdown]
# Não há forte predominância de nenhum estado civil.

# %%
df_count = df['gender'].value_counts().reset_index()
df_count.columns = ['gender', 'count']
fig = px.bar(
    df_count,
    x='gender',
    y='count',
    title='Gênero'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
df['gender'].value_counts(normalize=True) * 100
# Out:
# gender
# Female    50.420168
# Male      49.579832
# Name: proportion, dtype: float64

# %% [markdown]
# Também não há forte predominância de nenhum gênero.

# %%
df_count = df['education'].value_counts().reset_index()
df_count.columns = ['education', 'count']
fig = px.bar(
    df_count,
    x='education',
    y='count',
    title='Status Educação'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
df['education'].value_counts(normalize=True) * 100
# Out:
# education
# Bachelor's Degree      27.731092
# Master's Degree        22.689076
# Doctorate              18.487395
# High School Diploma    17.647059
# Associate's Degree     13.445378
# Name: proportion, dtype: float64

# %% [markdown]
# A maior parcela das pessoas possui nível superior ou mais (68%), sendo o nível superior completo a faixa de formação predominante com aproximadamente 28%.

# %%
df_count = df['home_ownership'].value_counts().reset_index()
df_count.columns = ['home_ownership', 'count']
fig = px.bar(
    df_count,
    x='home_ownership',
    y='count',
    title='Status moradia'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
df['home_ownership'].value_counts(normalize=True) * 100
# Out:
# home_ownership
# Owned     71.428571
# Rented    28.571429
# Name: proportion, dtype: float64

# %% [markdown]
# Mais de 70% da amostra é dona da própria casa o que sugere uma relativa estabilidade e constância.

# %%
df_count = df['credit_score'].value_counts().reset_index()
df_count.columns = ['credit_score', 'count']
fig = px.bar(
    df_count,
    x='credit_score',
    y='count',
    title='Crédito'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
df['credit_score'].value_counts(normalize=True) * 100
# Out:
# credit_score
# High       73.109244
# Average    20.168067
# Low         6.722689
# Name: proportion, dtype: float64

# %% [markdown]
# Poucos clientes possuem baixo score de crédito, sendo a maior parte deles financeiramente equilibrados.

# %% [markdown]
# **D) Realize a análise Bivariada.
# Tente responder as seguintes perguntas com gráficos seguidos de insights:**
#
#
#
# *   Existe relação entre a idade e o status civil? Os dados sugerem que sim, já que a distribuiçõ de idade varia com o estado civil, os clientes casados tendem a apresentar concentração acima de 40 anos.
# *   Qual a relação entre o score de crédito e o nível de escolaridade? os dados mostram que nas faixas de maior escolaridade estão concentrados os níveis mais altos de crédito e nas faixas de menor escolaridade scores mais baixo.
# *  O salário parece influenciar na idade? os dados sugerem que sim, já que nas faixas de menor idade estão concentrados os menores salários. Os slários tendem a "subir" até os 50 anos e depois apresenta pequena queda.
# * O salário parece influenciar no Score de Crédito? Aparentemente não muito, já que os grupos estão sobrepostos e existem lientes com diferentes faixas de renda nas 3 categorias de score.
# * Clientes com casa própria tendem a ter um score mais alto? Os dados mais uma vez sugerem que sim, pois os cliente donos dos próprios imóveis possuem o score mais alto.

# %%
fig = px.box(
    df,
    x='marital_status',
    y='age',
    title='Idade por Estado Civil'
)

fig.update_layout(width=800, height=500)
fig.show()

# %%
fig = px.histogram(
    df,
    x='education',
    color='credit_score',
    barmode='group',
    title='Score de Crédito por Nível de Escolaridade'
)
fig.update_layout(width=800, height=500)
fig.show()

# %%
fig = px.scatter(
    df,
    x='age',
    y='income',
    title='Relação entre Idade e Salário'
)
fig.update_layout(width=800, height=500)

fig.show()

# %%
fig = px.box(
    df,
    x='credit_score',
    y='income',
    title='Salário por Score de Crédito'
)
fig.update_layout(width=800, height=500)
fig.show()

# %%
fig = px.histogram(
    df,
    x='home_ownership',
    color='credit_score',
    barmode='group',
    title='Score de Crédito por Tipo de Moradia'
)
fig.update_layout(width=800, height=500)

fig.show()

# %% [markdown]
# **E) Que outras perguntas te parecem fazer sentido explorarmos a resposta para conhecermos mais nossa base de dados e o comportamento dos clientes?**
#
#  Elabore mais 3 perguntas e responda utilizando gráficos + insights.
#  <br>
#  Clientes com maior renda têm mais filhos? Os dados não sugerem nenhuma tendencia nesse sentido já que encontramos 0,1 e 2 filhos em todas as faixas de renda.
#   <br>
#  Pessoas com filhos têm score diferente? Aparentemente sim, pessoas com 1/2 filhos possuem score alto de crédito e nenhum registro de baixo. Talvez porque apresentem um melhor planejamento financeiro e estabilidade.
#   <br>
#  Idade influencia o score de crédito? os dados sugerem que sim poque pessoas mais velhas tendem a possuir score mais alto talvez pelo histórico mais longo que permite mapear melhor os comportamentos.

# %%
fig = px.box(
    df,
    x='number_of_children',
    y='income',
    title='Renda por Número de Filhos'
)
fig.update_layout(width=800, height=500)
fig.show()

# %%
fig = px.histogram(
    df,
    x='number_of_children',
    color='credit_score',
    barmode='group',
    title='Score de Crédito por Número de Filhos'
)
fig.update_layout(width=800, height=500)


fig.show()

# %%
fig = px.box(
    df,
    x='credit_score',
    y='age',
    title='Idade por Score de Crédito'
)

fig.update_layout(width=800, height=500)
fig.show()

# %% [markdown]
# # Etapa 3: Relize os passos que vimos no módulo 17, de Correlação, Balanceamento, atributos categóricos e divisão base treino e teste.
#
# **A) Vamos começar pela análise de correlação, plote da forma que achar melhor a análise de correlação, seja pela tabela ou pelo gráfico da matriz.**

# %%
df.select_dtypes(include=['number']).corr()
# Out:
#                          age    income  number_of_children
# age                 1.000000  0.615532           -0.062963
# income              0.615532  1.000000           -0.076310
# number_of_children -0.062963 -0.076310            1.000000

# %% [markdown]
# **B) Você encontrou variáveis que tem uma média ou alta correlação? Se sim, quais? Te parece fazer sentido essas variáveis terem alta correlação? Justifique.** <br> sim, mas apenas idade e salário (0.61) talvez porque pessoas mais velhas nesse conjunto de dados tiveram mais tempo para estudar, ampliar sua formação e obter melhores salários.

# %% [markdown]
# **C) Temos muitos atributos categóricos nessa base, não? Vamos realizar a o tratamento desses atributos utilizando Label Encoder ou one hot. Após, exclua as colunas categóricas.**

# %%
#transforma as ategoricas p fazer correlação de td
#transformando as colunas categoricas
print(df.columns)
colunas_credit = ['gender', 'marital_status', 'education', 'home_ownership']
df = pd.get_dummies(df, columns = colunas_credit, drop_first=True) #aplicando o one hot, pois não há ordem e já removendo com drop_first
df.head(10)
# Out:
# Index(['age', 'gender', 'income', 'education', 'marital_status',
#        'number_of_children', 'home_ownership', 'credit_score'],
#       dtype='str')
#           age    income  number_of_children credit_score  gender_Male  \
# 0   25.000000   50000.0                   0         High        False
# 1   30.000000  100000.0                   2         High         True
# 2   35.000000   75000.0                   1         High        False
# 3   40.000000  125000.0                   0         High         True
# 5   50.000000  150000.0                   0         High         True
# 6   26.000000   40000.0                   0      Average        False
# 7   31.000000   60000.0                   0      Average         True
# 8   37.507692   80000.0                   2         High        False
# 9   37.507692  105000.0                   0         High         True
# 10  37.507692   90000.0                   1         High        False
#
#     marital_status_Single  education_Bachelor's Degree  education_Doctorate  \
# 0                    True                         True                False
# 1                   False                        False                False
# 2                   False                        False                 True
# 3                    True                        False                False
# 5                   False                        False                False
# 6                    True                        False                False
# 7                    True                         True                False
# 8                   False                        False                False
# 9                    True                        False                 True
# 10                  False                        False                False
#
#     education_High School Diploma  education_Master's Degree  \
# 0                           False                      False
# 1                           False                       True
# 2                           False                      False
# 3                            True                      False
# 5                           False                       True
# 6                           False                      False
# 7                           False                      False
# 8                           False                       True
# 9                           False                      False
# 10                           True                      False
#
#     home_ownership_Rented
# 0                    True
# 1                   False
# 2                   False
# 3                   False
# 5                   False
# 6                    True
# 7                    True
# 8                   False
# 9                   False
# 10                  False

# %%
df.dtypes #é preciso verificar se converteu para inteiro-caso contr´rio ele não faz a correlação
# Out:
# age                              float64
# income                           float64
# number_of_children                 int64
# credit_score                         str
# gender_Male                         bool
# marital_status_Single               bool
# education_Bachelor's Degree         bool
# education_Doctorate                 bool
# education_High School Diploma       bool
# education_Master's Degree           bool
# home_ownership_Rented               bool
# dtype: object

# %%
for column in df.columns:
    if df[column].dtype =='bool':
        df[column] = df[column].astype(int)

# %%
df.dtypes
# Out:
# age                              float64
# income                           float64
# number_of_children                 int64
# credit_score                         str
# gender_Male                        int64
# marital_status_Single              int64
# education_Bachelor's Degree        int64
# education_Doctorate                int64
# education_High School Diploma      int64
# education_Master's Degree          int64
# home_ownership_Rented              int64
# dtype: object

# %% [markdown]
# **D) Vamos plotar novamente a correlação, agora observando com as variáveis categóricas. Identifique se temos novas variáveis com forte correlação.**

# %%
df.corr()
# Out:
#                                     age    income  number_of_children  \
# age                            1.000000  0.615532           -0.062963
# income                         0.615532  1.000000           -0.076310
# number_of_children            -0.062963 -0.076310            1.000000
# gender_Male                    0.251167  0.555464           -0.497402
# marital_status_Single         -0.422780 -0.432157           -0.668574
# education_Bachelor's Degree   -0.235976 -0.128636            0.194919
# education_Doctorate            0.163363  0.044671            0.129122
# education_High School Diploma  0.095896  0.006361           -0.197810
# education_Master's Degree      0.088357  0.299678            0.098139
# home_ownership_Rented         -0.597077 -0.664228           -0.444116
# credit_score_High              0.584061  0.699581            0.374524
# credit_score_Low              -0.191364 -0.463521           -0.197725
#
#                                gender_Male  marital_status_Single  \
# age                               0.251167              -0.422780
# income                            0.555464              -0.432157
# number_of_children               -0.497402              -0.668574
# gender_Male                       1.000000               0.272535
# marital_status_Single             0.272535               1.000000
# education_Bachelor's Degree      -0.155370              -0.095014
# education_Doctorate              -0.233846              -0.183578
# education_High School Diploma    -0.034849               0.059681
# education_Master's Degree         0.334423               0.022905
# home_ownership_Rented            -0.055031               0.662509
# credit_score_High                 0.132666              -0.593720
# credit_score_Low                 -0.280663               0.295741
#
#                                education_Bachelor's Degree  \
# age                                              -0.235976
# income                                           -0.128636
# number_of_children                                0.194919
# gender_Male                                      -0.155370
# marital_status_Single                            -0.095014
# education_Bachelor's Degree                       1.000000
# education_Doctorate                              -0.282436
# education_High School Diploma                    -0.274470
# education_Master's Degree                        -0.321655
# home_ownership_Rented                             0.150337
# credit_score_High                                -0.130939
# credit_score_Low                                 -0.158783
#
#                                education_Doctorate  \
# age                                       0.163363
# income                                    0.044671
# number_of_children                        0.129122
# gender_Male                              -0.233846
# marital_status_Single                    -0.183578
# education_Bachelor's Degree              -0.282436
# education_Doctorate                       1.000000
# education_High School Diploma            -0.229888
# education_Master's Degree                -0.269408
# home_ownership_Rented                    -0.266667
# credit_score_High                         0.252667
# credit_score_Low                         -0.132991
#
#                                education_High School Diploma  \
# age                                                 0.095896
# income                                              0.006361
# number_of_children                                 -0.197810
# gender_Male                                        -0.034849
# marital_status_Single                               0.059681
# education_Bachelor's Degree                        -0.274470
# education_Doctorate                                -0.229888
# education_High School Diploma                       1.000000
# education_Master's Degree                          -0.261810
# home_ownership_Rented                               0.088351
# credit_score_High                                  -0.108309
# credit_score_Low                                    0.401569
#
#                                education_Master's Degree  \
# age                                             0.088357
# income                                          0.299678
# number_of_children                              0.098139
# gender_Male                                     0.334423
# marital_status_Single                           0.022905
# education_Bachelor's Degree                    -0.321655
# education_Doctorate                            -0.269408
# education_High School Diploma                  -0.261810
# education_Master's Degree                       1.000000
# home_ownership_Rented                          -0.313914
# credit_score_High                               0.343935
# credit_score_Low                               -0.151458
#
#                                home_ownership_Rented  credit_score_High  \
# age                                        -0.597077           0.584061
# income                                     -0.664228           0.699581
# number_of_children                         -0.444116           0.374524
# gender_Male                                -0.055031           0.132666
# marital_status_Single                       0.662509          -0.593720
# education_Bachelor's Degree                 0.150337          -0.130939
# education_Doctorate                        -0.266667           0.252667
# education_High School Diploma               0.088351          -0.108309
# education_Master's Degree                  -0.313914           0.343935
# home_ownership_Rented                       1.000000          -0.873341
# credit_score_High                          -0.873341           1.000000
# credit_score_Low                            0.422042          -0.440369
#
#                                credit_score_Low
# age                                   -0.191364
# income                                -0.463521
# number_of_children                    -0.197725
# gender_Male                           -0.280663
# marital_status_Single                  0.295741
# education_Bachelor's Degree           -0.158783
# education_Doctorate                   -0.132991
# education_High School Diploma          0.401569
# education_Master's Degree             -0.151458
# home_ownership_Rented                  0.422042
# credit_score_High                     -0.440369
# credit_score_Low                       1.000000

# %% [markdown]
# idade e:<br>
# salário 0.61 (talvez mais idade para esse grupo tenha ampliado a possibilidade de expandir a formação)
# education bachelors degree -0.23,
# education doctorate 0.16,
# marital status -0.42(talvez mais idade para esse grupo seja uma fase mais atrelada a esse tipo de compromisso),
# home ownership -0.59(talvez mais idade para esse grupo tenha ampliado a possibilidade de expandir a formação e também ampliado os recursos e ganhos para comprar a casa),
# credit score high 0.58(talvez todos os fatores acima e ainda um histórico para esse grupo ter como base para avaliar a concessão de crédito)
# <br>
#
# salário e:<br>
# idade 0.61,
# marital status -0.43,
# education master's degree 0.30,
# home ownership -0.66,
# credit score high 0.70,
# credit score low -0.46(talvez para esse grupo a faixa de renda influencie diretamento o quanto de crédito será fornecido).
# <br>
#
# number_of_children e:<br>
# marital status -0.67 (talvez para esse grupo a opção pelo casamento esteja ligada aos filhos),
# gender male -0.49,
# home ownership -0.44(talvez para esse grupo a opção pelo casamento esteja ligada aos filhos e a compra da casa para família),
# credit score high 0.37 (talvez todos os fatores acima e ainda um histórico para esse grupo ter como base para avaliar a concessão de crédito)
# <br>
#
# gender male e:<br>
# income 0.55
# number_of_children -0.50
# <br>
#
# marital status_single e:<br>
# number_of_children -0.67(talvez para esse grupo a opção pelo casamento esteja ligada aos filhos),
# home ownership 0.66,
# credit score high -0.59,
# income -0.43,
# age -0.42,
# <br>
#
# home ownership (rented) e:<br>
# credit score high -0.87,
# income -0.66,
# age -0.60,
# marital status 0.66
# <br>
#
# credit score high e:<br>
# income 0.70,
# home ownership -0.87,
# age 0.58,
# marital status -0.59
# <br> Aparentemente a variável alvo score de crédito está altamente ligada ao salário, compra da casa, idade e estado civil, sendo esses fatores também interligados.

# %%
#seu código aqui

# %% [markdown]
# **F) Faça a separação da base em treino e teste e verifique utilizando shape:**

# %%
x = df.drop('credit_score', axis = 1)
y = df['credit_score']
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size = 0.25, random_state =42)

# %%
print('tamanho', X_train.shape)
# Out:
# tamanho (86, 10)

# %%
print(X_train.columns)
# Out:
# Index(['age', 'income', 'number_of_children', 'gender_Male',
#        'marital_status_Single', 'education_Bachelor's Degree',
#        'education_Doctorate', 'education_High School Diploma',
#        'education_Master's Degree', 'home_ownership_Rented'],
#       dtype='str')

# %%
print('tamanho', X_test.shape)
# Out:
# tamanho (29, 10)

# %%
print('tamanho', Y_train.shape)
# Out:
# tamanho (86,)

# %%
print('tamanho', Y_test.shape)
# Out:
# tamanho (29,)

# %% [markdown]
# **G) É hora de verificar se nossa coluna de Score de crédito está balanceada, verifique através de um gráfico e traga sua opinião acerca do balanceamento.**

# %%
credit = df['credit_score'].value_counts()
plt.figure(figsize=(8,6))
credit.plot(kind='bar', color = ['blue', 'yellow'])
print((df['credit_score'].value_counts(normalize = True) *100))
# Out:
# credit_score
# High       72.173913
# Average    20.869565
# Low         6.956522
# Name: proportion, dtype: float64

# %% [markdown]
# **H) Vamos realizar o balancecamento dos dados da coluna de credit score.**
# Se lembre que realizazmos apenas para a base de treino.

# %% [markdown]
# sim, está desbalanceado porque a base teste possui 73,10 % High ainda que o modelo não estivesse bom ele acertaria 73% "chutando" high.

# %%
from imblearn.over_sampling import RandomOverSampler
ros = RandomOverSampler(random_state=42)
X_train_balanced, Y_train_balanced = ros.fit_resample(X_train, Y_train)
print('Distribuição')
print(Y_train_balanced.value_counts())
print('Balanço em y_train')
print(Y_train.value_counts())
X_train_balanced.to_csv('X_train_balanced.csv', index=False)
Y_train_balanced.to_csv('Y_train_balanced.csv', index=False)
Y_test.to_csv('Y_test.csv', index=False)
X_test.to_csv('X_test.csv', index=False)
# Out:
# Distribuição
# credit_score
# High       61
# Average    61
# Low        61
# Name: count, dtype: int64
# Balanço em y_train
# credit_score
# High       61
# Average    20
# Low         5
# Name: count, dtype: int64

# %% [markdown]
# Como só tinham 5 exemplos de low optei por ampliar/ duplicar o número de registros porque assim o modelo não vai ignorar a categoria, mas também por outro lado ele pode overfitting.

# %%
print('Antes:', X_train.shape)
print('Depois:', X_train_balanced.shape) #o x aumentou junto com o y
# Out:
# Antes: (86, 10)
# Depois: (183, 10)

# %%
print(len(X_train))
print(len(X_train_balanced))
# Out:
# 86
# 183

# %%
# !pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\regina\anaconda3\lib\site-packages (0.14.0)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\regina\anaconda3\lib\site-packages (from imbalanced-learn) (2.3.5)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\regina\anaconda3\lib\site-packages (from imbalanced-learn) (1.16.3)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\regina\anaconda3\lib\site-packages (from imbalanced-learn) (1.7.2)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\regina\anaconda3\lib\site-packages (from imbalanced-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\regina\anaconda3\lib\site-packages (from imbalanced-learn) (3.5.0)

# %%
import sys
print(sys.executable)
# Out:
# C:\Users\Regina\AppData\Local\Programs\Python\Python313\python.exe

# %%
import sys
# !{sys.executable} -m pip install imbalanced-learn
# Out:
# Requirement already satisfied: imbalanced-learn in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (0.14.1)
# Requirement already satisfied: numpy<3,>=1.25.2 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (2.4.1)
# Requirement already satisfied: scipy<2,>=1.11.4 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.17.0)
# Requirement already satisfied: scikit-learn<2,>=1.4.2 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.8.0)
# Requirement already satisfied: sklearn-compat<0.2,>=0.1.5 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (0.1.5)
# Requirement already satisfied: joblib<2,>=1.2.0 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in c:\users\regina\appdata\local\programs\python\python313\lib\site-packages (from imbalanced-learn) (3.6.0)
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: C:\Users\Regina\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip

# %%
print(Y_train.value_counts())
# Out:
# credit_score
# High       61
# Average    20
# Low         5
# Name: count, dtype: int64
